# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.applications import EfficientNetB0
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.callbacks import TensorBoard
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, UpSampling2D, BatchNormalization

# %%
for dirname, _, filenames in os.walk('Seminar'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']
labels = ['glioma','notumor','meningioma','pituitary']

# %%
X_train = []
y_train = []
image_size = 80
for i in labels:
    folderPath = os.path.join('Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
# Out:
# 100%|██████████| 1321/1321 [00:24<00:00, 54.01it/s]
# 100%|██████████| 1595/1595 [00:30<00:00, 52.58it/s]
# 100%|██████████| 1339/1339 [00:26<00:00, 49.85it/s]
# 100%|██████████| 1457/1457 [00:30<00:00, 47.45it/s]
# 100%|██████████| 300/300 [00:05<00:00, 56.77it/s]
# 100%|██████████| 405/405 [00:06<00:00, 66.52it/s]
# 100%|██████████| 306/306 [00:05<00:00, 58.66it/s]
# 100%|██████████| 300/300 [00:05<00:00, 59.06it/s]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_train, y_train = shuffle(X_train,y_train, random_state=101)
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
# Data Augmentation
datagen = ImageDataGenerator(rotation_range=90, vertical_flip=True)

# Augment the training data and concatenate the original data with augmented data
X_train_augmented, y_train_augmented = [], []

for batch_X, batch_y in datagen.flow(X_train, y_train, batch_size=16, shuffle=False):
    X_train_augmented.append(batch_X)
    y_train_augmented.append(batch_y)
    if len(X_train_augmented) * 16 >= len(X_train):  # Stop after augmenting enough samples
        break

X_train_augmented = np.concatenate(X_train_augmented, axis=0)
y_train_augmented = np.concatenate(y_train_augmented, axis=0)

# Concatenate original and augmented data
X_train = np.concatenate((X_train, X_train_augmented), axis=0)
y_train = np.concatenate((y_train, y_train_augmented), axis=0)
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
from keras.models import Model
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

input_img = Input(shape=(80, 80, 3))  
# 2D CNN Layers
x = Conv2D(64, (2, 2), activation='relu', padding='same')(input_img)
x = Conv2D(64, (2, 2), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)

x = Conv2D(32, (2, 2), activation='relu', padding='same')(x)
x = Conv2D(32, (2, 2), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)

x = Conv2D(16, (2, 2), activation='relu', padding='same')(x)
x = Conv2D(16, (2, 2), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)

# Fully connected layers
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.1)(x)

# Output layer
output = Dense(4, activation='softmax')(x)  # Adjust the number of classes if needed (4 classes here)

# Create the model
cnn_model = Model(inputs=input_img, outputs=output)
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("cnn_crossval2.keras",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
# Initialize KFold cross-validation
from sklearn.model_selection import KFold
# Initialize KFold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=101)

# To store results for each fold
fold_no = 1
train_acc_per_fold = []
val_acc_per_fold = []
train_loss_per_fold = []
val_loss_per_fold = []

# Cross-validation loop
for train_index, val_index in kf.split(X_train):
    print(f'Training fold {fold_no}')
    
    # Split the data into train and validation sets for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]
    
    # Create and compile a new model for each fold
    cnn_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    
    # Train the model
    history = cnn_model.fit(X_fold_train, y_fold_train, epochs=12, batch_size=32, verbose=1, 
                            validation_data=(X_fold_val, y_fold_val),
                            callbacks=[tensorboard, checkpoint, reduce_lr])
    
    # Evaluate model on validation set
    val_loss, val_accuracy = cnn_model.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Validation Accuracy for fold {fold_no}: {val_accuracy * 100:.2f}%')
    
    # Store the results
    train_acc_per_fold.append(history.history['accuracy'][-1])
    val_acc_per_fold.append(val_accuracy)
    train_loss_per_fold.append(history.history['loss'][-1])
    val_loss_per_fold.append(val_loss)
    
    fold_no += 1
# Out:
# Training fold 1
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6752 - loss: 0.9393
# Epoch 1: val_accuracy improved from -inf to 0.81962, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 116s 303ms/step - accuracy: 0.6753 - loss: 0.9386 - val_accuracy: 0.8196 - val_loss: 0.5242 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.8295 - loss: 0.4211
# Epoch 2: val_accuracy did not improve from 0.81962
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 101s 282ms/step - accuracy: 0.8296 - loss: 0.4210 - val_accuracy: 0.7532 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8879 - loss: 0.2918
# Epoch 3: val_accuracy improved from 0.81962 to 0.90111, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 95s 266ms/step - accuracy: 0.8879 - loss: 0.2917 - val_accuracy: 0.9011 - val_loss: 0.2703 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9204 - loss: 0.2148
# Epoch 4: val_accuracy did not improve from 0.90111
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 315ms/step - accuracy: 0.9204 - loss: 0.2148 - val_accuracy: 0.8513 - val_loss: 0.4193 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9469 - loss: 0.1437
# Epoch 5: val_accuracy did not improve from 0.90111
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 97s 272ms/step - accuracy: 0.9469 - loss: 0.1437 - val_accuracy: 0.8995 - val_loss: 0.3256 - learning_rate: 0.0010
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9745 - loss: 0.0770
# Epoch 6: val_accuracy did not improve from 0.90111
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 108s 304ms/step - accuracy: 0.9745 - loss: 0.0770 - val_accuracy: 0.8892 - val_loss: 0.3587 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9879 - loss: 0.0402
# Epoch 7: val_accuracy improved from 0.90111 to 0.93513, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 97s 273ms/step - accuracy: 0.9879 - loss: 0.0402 - val_accuracy: 0.9351 - val_loss: 0.1972 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9905 - loss: 0.0344
# Epoch 8: val_accuracy did not improve from 0.93513
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 102s 285ms/step - accuracy: 0.9905 - loss: 0.0344 - val_accuracy: 0.9335 - val_loss: 0.1945 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9938 - loss: 0.0247
# Epoch 9: val_accuracy did not improve from 0.93513
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 121s 339ms/step - accuracy: 0.9938 - loss: 0.0247 - val_accuracy: 0.9351 - val_loss: 0.1987 - learning_rate: 3.0000e-04
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9933 - loss: 0.0200
# Epoch 10: val_accuracy improved from 0.93513 to 0.94304, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 102s 286ms/step - accuracy: 0.9933 - loss: 0.0200 - val_accuracy: 0.9430 - val_loss: 0.1904 - learning_rate: 9.0000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9969 - loss: 0.0138
# Epoch 11: val_accuracy did not improve from 0.94304
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 158s 444ms/step - accuracy: 0.9969 - loss: 0.0138 - val_accuracy: 0.9399 - val_loss: 0.1925 - learning_rate: 9.0000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9970 - loss: 0.0129
# Epoch 12: val_accuracy improved from 0.94304 to 0.94620, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 151s 425ms/step - accuracy: 0.9970 - loss: 0.0129 - val_accuracy: 0.9462 - val_loss: 0.1922 - learning_rate: 9.0000e-05
# Validation Accuracy for fold 1: 94.62%
# Training fold 2
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9615 - loss: 0.1139
# Epoch 1: val_accuracy did not improve from 0.94620
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 102s 272ms/step - accuracy: 0.9615 - loss: 0.1140 - val_accuracy: 0.9019 - val_loss: 0.3625 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9672 - loss: 0.0988
# Epoch 2: val_accuracy improved from 0.94620 to 0.96282, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 92s 259ms/step - accuracy: 0.9672 - loss: 0.0987 - val_accuracy: 0.9628 - val_loss: 0.1426 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9769 - loss: 0.0710
# Epoch 3: val_accuracy did not improve from 0.96282
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 92s 259ms/step - accuracy: 0.9769 - loss: 0.0710 - val_accuracy: 0.9573 - val_loss: 0.1543 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9754 - loss: 0.0730
# Epoch 4: val_accuracy did not improve from 0.96282
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 106s 298ms/step - accuracy: 0.9754 - loss: 0.0731 - val_accuracy: 0.9454 - val_loss: 0.1536 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9888 - loss: 0.0300
# Epoch 5: val_accuracy improved from 0.96282 to 0.97231, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 107s 301ms/step - accuracy: 0.9888 - loss: 0.0300 - val_accuracy: 0.9723 - val_loss: 0.0726 - learning_rate: 3.0000e-04
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9956 - loss: 0.0135
# Epoch 6: val_accuracy improved from 0.97231 to 0.98339, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 128s 359ms/step - accuracy: 0.9956 - loss: 0.0135 - val_accuracy: 0.9834 - val_loss: 0.0499 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9980 - loss: 0.0076
# Epoch 7: val_accuracy did not improve from 0.98339
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 156s 439ms/step - accuracy: 0.9980 - loss: 0.0076 - val_accuracy: 0.9826 - val_loss: 0.0422 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9982 - loss: 0.0069
# Epoch 8: val_accuracy improved from 0.98339 to 0.98418, saving model to cnn_crossval2.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 131s 368ms/step - accuracy: 0.9982 - loss: 0.0069 - val_accuracy: 0.9842 - val_loss: 0.0414 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9992 - loss: 0.0050
# Epoch 9: val_accuracy improved from 0.98418 to 0.98813, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 128s 360ms/step - accuracy: 0.9992 - loss: 0.0050 - val_accuracy: 0.9881 - val_loss: 0.0350 - learning_rate: 9.0000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9992 - loss: 0.0040
# Epoch 10: val_accuracy did not improve from 0.98813
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 131s 368ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9881 - val_loss: 0.0390 - learning_rate: 9.0000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9991 - loss: 0.0048
# Epoch 11: val_accuracy did not improve from 0.98813
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 134s 378ms/step - accuracy: 0.9991 - loss: 0.0048 - val_accuracy: 0.9866 - val_loss: 0.0375 - learning_rate: 9.0000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9994 - loss: 0.0031
# Epoch 12: val_accuracy did not improve from 0.98813
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 135s 380ms/step - accuracy: 0.9994 - loss: 0.0031 - val_accuracy: 0.9866 - val_loss: 0.0369 - learning_rate: 2.7000e-05
# Validation Accuracy for fold 2: 98.66%
# Training fold 3
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9832 - loss: 0.0489
# Epoch 1: val_accuracy did not improve from 0.98813
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 154s 401ms/step - accuracy: 0.9832 - loss: 0.0490 - val_accuracy: 0.9850 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.9840 - loss: 0.0505
# Epoch 2: val_accuracy did not improve from 0.98813
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 136s 382ms/step - accuracy: 0.9840 - loss: 0.0505 - val_accuracy: 0.9652 - val_loss: 0.1136 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9819 - loss: 0.0615
# Epoch 3: val_accuracy did not improve from 0.98813
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 122s 344ms/step - accuracy: 0.9818 - loss: 0.0616 - val_accuracy: 0.9691 - val_loss: 0.0980 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9887 - loss: 0.0355
# Epoch 4: val_accuracy improved from 0.98813 to 0.99209, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 110s 309ms/step - accuracy: 0.9887 - loss: 0.0355 - val_accuracy: 0.9921 - val_loss: 0.0231 - learning_rate: 3.0000e-04
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9944 - loss: 0.0148
# Epoch 5: val_accuracy improved from 0.99209 to 0.99684, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 334ms/step - accuracy: 0.9944 - loss: 0.0148 - val_accuracy: 0.9968 - val_loss: 0.0096 - learning_rate: 3.0000e-04
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9987 - loss: 0.0056
# Epoch 6: val_accuracy did not improve from 0.99684
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 120s 338ms/step - accuracy: 0.9987 - loss: 0.0056 - val_accuracy: 0.9968 - val_loss: 0.0125 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9984 - loss: 0.0051
# Epoch 7: val_accuracy did not improve from 0.99684
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 121s 339ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9960 - val_loss: 0.0123 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9986 - loss: 0.0037
# Epoch 8: val_accuracy did not improve from 0.99684
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 148s 415ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9960 - val_loss: 0.0123 - learning_rate: 9.0000e-05
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9985 - loss: 0.0040
# Epoch 9: val_accuracy improved from 0.99684 to 0.99842, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 320ms/step - accuracy: 0.9985 - loss: 0.0040 - val_accuracy: 0.9984 - val_loss: 0.0088 - learning_rate: 9.0000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9996 - loss: 0.0023
# Epoch 10: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 117s 330ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 0.9968 - val_loss: 0.0095 - learning_rate: 9.0000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9997 - loss: 0.0022
# Epoch 11: val_accuracy did not improve from 0.99842
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 116s 326ms/step - accuracy: 0.9997 - loss: 0.0022 - val_accuracy: 0.9968 - val_loss: 0.0104 - learning_rate: 9.0000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9997 - loss: 0.0019
# Epoch 12: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 117s 328ms/step - accuracy: 0.9997 - loss: 0.0019 - val_accuracy: 0.9984 - val_loss: 0.0085 - learning_rate: 2.7000e-05
# Validation Accuracy for fold 3: 99.84%
# Training fold 4
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9872 - loss: 0.0388
# Epoch 1: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 120s 314ms/step - accuracy: 0.9872 - loss: 0.0389 - val_accuracy: 0.9842 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9874 - loss: 0.0392
# Epoch 2: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 335ms/step - accuracy: 0.9874 - loss: 0.0393 - val_accuracy: 0.9778 - val_loss: 0.0685 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9823 - loss: 0.0572
# Epoch 3: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 122s 342ms/step - accuracy: 0.9823 - loss: 0.0572 - val_accuracy: 0.9897 - val_loss: 0.0278 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9903 - loss: 0.0309
# Epoch 4: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 334ms/step - accuracy: 0.9903 - loss: 0.0309 - val_accuracy: 0.9794 - val_loss: 0.0562 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9847 - loss: 0.0576
# Epoch 5: val_accuracy did not improve from 0.99842
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 317ms/step - accuracy: 0.9847 - loss: 0.0576 - val_accuracy: 0.9763 - val_loss: 0.0904 - learning_rate: 0.0010
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9922 - loss: 0.0265
# Epoch 6: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 312ms/step - accuracy: 0.9922 - loss: 0.0265 - val_accuracy: 0.9929 - val_loss: 0.0200 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9983 - loss: 0.0063
# Epoch 7: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 107s 301ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9929 - val_loss: 0.0146 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9995 - loss: 0.0047
# Epoch 8: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 124s 348ms/step - accuracy: 0.9995 - loss: 0.0047 - val_accuracy: 0.9945 - val_loss: 0.0155 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 9: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 117s 329ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9945 - val_loss: 0.0152 - learning_rate: 3.0000e-04
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9982 - loss: 0.0039
# Epoch 10: val_accuracy did not improve from 0.99842
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 318ms/step - accuracy: 0.9982 - loss: 0.0039 - val_accuracy: 0.9921 - val_loss: 0.0294 - learning_rate: 3.0000e-04
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9989 - loss: 0.0043
# Epoch 11: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 102s 285ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 0.9953 - val_loss: 0.0154 - learning_rate: 9.0000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 12: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 115s 322ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9968 - val_loss: 0.0125 - learning_rate: 9.0000e-05
# Validation Accuracy for fold 4: 99.68%
# Training fold 5
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9927 - loss: 0.0244
# Epoch 1: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 122s 326ms/step - accuracy: 0.9927 - loss: 0.0245 - val_accuracy: 0.9905 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9904 - loss: 0.0325
# Epoch 2: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 319ms/step - accuracy: 0.9904 - loss: 0.0325 - val_accuracy: 0.9842 - val_loss: 0.0581 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9871 - loss: 0.0415
# Epoch 3: val_accuracy did not improve from 0.99842
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 117s 329ms/step - accuracy: 0.9871 - loss: 0.0415 - val_accuracy: 0.9913 - val_loss: 0.0434 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9949 - loss: 0.0154
# Epoch 4: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 124s 348ms/step - accuracy: 0.9949 - loss: 0.0154 - val_accuracy: 0.9976 - val_loss: 0.0090 - learning_rate: 3.0000e-04
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9975 - loss: 0.0088
# Epoch 5: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 118s 332ms/step - accuracy: 0.9975 - loss: 0.0088 - val_accuracy: 0.9984 - val_loss: 0.0053 - learning_rate: 3.0000e-04
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9990 - loss: 0.0029
# Epoch 6: val_accuracy did not improve from 0.99842
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 318ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.9984 - val_loss: 0.0052 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9998 - loss: 0.0018
# Epoch 7: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 115s 322ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 0.9968 - val_loss: 0.0049 - learning_rate: 9.0000e-05
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 8: val_accuracy did not improve from 0.99842
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 132s 371ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9976 - val_loss: 0.0062 - learning_rate: 9.0000e-05
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9993 - loss: 0.0025
# Epoch 9: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 321ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9976 - val_loss: 0.0067 - learning_rate: 2.7000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9998 - loss: 0.0013
# Epoch 10: val_accuracy did not improve from 0.99842
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 316ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9976 - val_loss: 0.0067 - learning_rate: 2.7000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9997 - loss: 0.0016
# Epoch 11: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 319ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9976 - val_loss: 0.0064 - learning_rate: 8.1000e-06
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9992 - loss: 0.0025
# Epoch 12: val_accuracy did not improve from 0.99842
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 317ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9976 - val_loss: 0.0062 - learning_rate: 8.1000e-06
# Validation Accuracy for fold 5: 99.76%
# Training fold 6
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9945 - loss: 0.0203
# Epoch 1: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 121s 325ms/step - accuracy: 0.9945 - loss: 0.0204 - val_accuracy: 0.9802 - val_loss: 0.0496 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9913 - loss: 0.0307
# Epoch 2: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 313ms/step - accuracy: 0.9913 - loss: 0.0307 - val_accuracy: 0.9858 - val_loss: 0.0561 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9878 - loss: 0.0598
# Epoch 3: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 315ms/step - accuracy: 0.9878 - loss: 0.0598 - val_accuracy: 0.9771 - val_loss: 0.0642 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9908 - loss: 0.0387
# Epoch 4: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 109s 305ms/step - accuracy: 0.9908 - loss: 0.0387 - val_accuracy: 0.9960 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9960 - loss: 0.0150
# Epoch 5: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 115s 322ms/step - accuracy: 0.9960 - loss: 0.0150 - val_accuracy: 0.9905 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9963 - loss: 0.0120
# Epoch 6: val_accuracy did not improve from 0.99842
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 320ms/step - accuracy: 0.9963 - loss: 0.0121 - val_accuracy: 0.9597 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9928 - loss: 0.0227
# Epoch 7: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 104s 292ms/step - accuracy: 0.9928 - loss: 0.0227 - val_accuracy: 0.9976 - val_loss: 0.0124 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9993 - loss: 0.0027
# Epoch 8: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 335ms/step - accuracy: 0.9993 - loss: 0.0027 - val_accuracy: 0.9976 - val_loss: 0.0097 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9996 - loss: 0.0018
# Epoch 9: val_accuracy did not improve from 0.99842
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 128s 360ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9976 - val_loss: 0.0073 - learning_rate: 3.0000e-04
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9989 - loss: 0.0065
# Epoch 10: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 108s 302ms/step - accuracy: 0.9989 - loss: 0.0065 - val_accuracy: 0.9976 - val_loss: 0.0063 - learning_rate: 9.0000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9996 - loss: 0.0032
# Epoch 11: val_accuracy did not improve from 0.99842
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 104s 292ms/step - accuracy: 0.9996 - loss: 0.0032 - val_accuracy: 0.9976 - val_loss: 0.0078 - learning_rate: 9.0000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9999 - loss: 0.0011
# Epoch 12: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 109s 307ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9976 - val_loss: 0.0076 - learning_rate: 2.7000e-05
# Validation Accuracy for fold 6: 99.76%
# Training fold 7
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9949 - loss: 0.0159
# Epoch 1: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 322ms/step - accuracy: 0.9949 - loss: 0.0159 - val_accuracy: 0.9921 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9901 - loss: 0.0301
# Epoch 2: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 113s 316ms/step - accuracy: 0.9901 - loss: 0.0300 - val_accuracy: 0.9889 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9941 - loss: 0.0268
# Epoch 3: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 106s 298ms/step - accuracy: 0.9940 - loss: 0.0268 - val_accuracy: 0.9960 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9908 - loss: 0.0331
# Epoch 4: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 105s 296ms/step - accuracy: 0.9908 - loss: 0.0331 - val_accuracy: 0.9889 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9912 - loss: 0.0260
# Epoch 5: val_accuracy did not improve from 0.99842
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 312ms/step - accuracy: 0.9912 - loss: 0.0260 - val_accuracy: 0.9968 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9970 - loss: 0.0113
# Epoch 6: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 312ms/step - accuracy: 0.9970 - loss: 0.0113 - val_accuracy: 0.9984 - val_loss: 0.0032 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9989 - loss: 0.0058
# Epoch 7: val_accuracy did not improve from 0.99842
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 96s 268ms/step - accuracy: 0.9989 - loss: 0.0058 - val_accuracy: 0.9984 - val_loss: 0.0024 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9993 - loss: 0.0024
# Epoch 8: val_accuracy improved from 0.99842 to 0.99921, saving model to cnn_crossval2.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 118s 331ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.9992 - val_loss: 0.0017 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9989 - loss: 0.0025
# Epoch 9: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 313ms/step - accuracy: 0.9989 - loss: 0.0025 - val_accuracy: 0.9992 - val_loss: 0.0015 - learning_rate: 9.0000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9993 - loss: 0.0022
# Epoch 10: val_accuracy did not improve from 0.99921
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 104s 291ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 0.9992 - val_loss: 0.0019 - learning_rate: 9.0000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9994 - loss: 0.0021
# Epoch 11: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 106s 296ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9992 - val_loss: 0.0020 - learning_rate: 2.7000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9998 - loss: 0.0011
# Epoch 12: val_accuracy did not improve from 0.99921
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 319ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9992 - val_loss: 0.0019 - learning_rate: 2.7000e-05
# Validation Accuracy for fold 7: 99.92%
# Training fold 8
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9962 - loss: 0.0122
# Epoch 1: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 115s 310ms/step - accuracy: 0.9962 - loss: 0.0122 - val_accuracy: 0.9897 - val_loss: 0.0453 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9861 - loss: 0.0503
# Epoch 2: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 118s 331ms/step - accuracy: 0.9861 - loss: 0.0503 - val_accuracy: 0.9905 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9946 - loss: 0.0218
# Epoch 3: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 320ms/step - accuracy: 0.9946 - loss: 0.0218 - val_accuracy: 0.9945 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9902 - loss: 0.0481
# Epoch 4: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 109s 307ms/step - accuracy: 0.9902 - loss: 0.0481 - val_accuracy: 0.9953 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9937 - loss: 0.0197
# Epoch 5: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 109s 305ms/step - accuracy: 0.9937 - loss: 0.0197 - val_accuracy: 0.9968 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9976 - loss: 0.0075
# Epoch 6: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 315ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9628 - val_loss: 0.1742 - learning_rate: 0.0010
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9908 - loss: 0.0412
# Epoch 7: val_accuracy did not improve from 0.99921
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 114s 321ms/step - accuracy: 0.9908 - loss: 0.0412 - val_accuracy: 0.9929 - val_loss: 0.0194 - learning_rate: 0.0010
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9949 - loss: 0.0135
# Epoch 8: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 118s 333ms/step - accuracy: 0.9949 - loss: 0.0135 - val_accuracy: 0.9976 - val_loss: 0.0107 - learning_rate: 3.0000e-04
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9982 - loss: 0.0080
# Epoch 9: val_accuracy did not improve from 0.99921
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 116s 327ms/step - accuracy: 0.9982 - loss: 0.0080 - val_accuracy: 0.9992 - val_loss: 0.0026 - learning_rate: 3.0000e-04
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 10: val_accuracy improved from 0.99921 to 1.00000, saving model to cnn_crossval2.keras
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 115s 322ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 7.2960e-04 - learning_rate: 3.0000e-04
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9997 - loss: 0.0020
# Epoch 11: val_accuracy did not improve from 1.00000
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 312ms/step - accuracy: 0.9997 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 4.6003e-04 - learning_rate: 3.0000e-04
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9991 - loss: 0.0027
# Epoch 12: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 316ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 3.8055e-04 - learning_rate: 9.0000e-05
# Validation Accuracy for fold 8: 100.00%
# Training fold 9
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9971 - loss: 0.0105
# Epoch 1: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 175s 464ms/step - accuracy: 0.9971 - loss: 0.0105 - val_accuracy: 0.9984 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9966 - loss: 0.0145
# Epoch 2: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 124s 349ms/step - accuracy: 0.9966 - loss: 0.0145 - val_accuracy: 0.9486 - val_loss: 0.3088 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9892 - loss: 0.0392
# Epoch 3: val_accuracy did not improve from 1.00000
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 130s 364ms/step - accuracy: 0.9892 - loss: 0.0392 - val_accuracy: 0.9960 - val_loss: 0.0153 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9960 - loss: 0.0157
# Epoch 4: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 125s 351ms/step - accuracy: 0.9960 - loss: 0.0157 - val_accuracy: 0.9976 - val_loss: 0.0062 - learning_rate: 3.0000e-04
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9976 - loss: 0.0088
# Epoch 5: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 125s 353ms/step - accuracy: 0.9976 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 8.9423e-04 - learning_rate: 3.0000e-04
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9986 - loss: 0.0028
# Epoch 6: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.9986 - loss: 0.0028 - val_accuracy: 0.9992 - val_loss: 0.0011 - learning_rate: 3.0000e-04
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9991 - loss: 0.0031
# Epoch 7: val_accuracy did not improve from 1.00000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 311ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 7.5718e-04 - learning_rate: 3.0000e-04
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9998 - loss: 7.1752e-04
# Epoch 8: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 120s 337ms/step - accuracy: 0.9998 - loss: 7.1790e-04 - val_accuracy: 1.0000 - val_loss: 5.1635e-04 - learning_rate: 9.0000e-05
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9996 - loss: 0.0020
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 112s 315ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 4.1967e-04 - learning_rate: 9.0000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9999 - loss: 5.7748e-04
# Epoch 10: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 123s 344ms/step - accuracy: 0.9999 - loss: 5.7736e-04 - val_accuracy: 1.0000 - val_loss: 4.4419e-04 - learning_rate: 2.7000e-05
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9999 - loss: 0.0014
# Epoch 11: val_accuracy did not improve from 1.00000
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 124s 348ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 4.1384e-04 - learning_rate: 2.7000e-05
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 8.1788e-04
# Epoch 12: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 120s 336ms/step - accuracy: 0.9997 - loss: 8.1790e-04 - val_accuracy: 1.0000 - val_loss: 4.0093e-04 - learning_rate: 8.1000e-06
# Validation Accuracy for fold 9: 100.00%
# Training fold 10
# Epoch 1/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9973 - loss: 0.0119
# Epoch 1: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 131s 351ms/step - accuracy: 0.9973 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 2/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9945 - loss: 0.0214
# Epoch 2: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 121s 340ms/step - accuracy: 0.9945 - loss: 0.0214 - val_accuracy: 0.9842 - val_loss: 0.0643 - learning_rate: 0.0010
# Epoch 3/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9939 - loss: 0.0272
# Epoch 3: val_accuracy did not improve from 1.00000
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 335ms/step - accuracy: 0.9939 - loss: 0.0272 - val_accuracy: 0.9976 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 4/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9981 - loss: 0.0091
# Epoch 4: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 333ms/step - accuracy: 0.9981 - loss: 0.0091 - val_accuracy: 0.9992 - val_loss: 7.1155e-04 - learning_rate: 3.0000e-04
# Epoch 5/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9983 - loss: 0.0050
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 130s 365ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 1.2510e-04 - learning_rate: 3.0000e-04
# Epoch 6/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9991 - loss: 0.0058
# Epoch 6: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 121s 340ms/step - accuracy: 0.9991 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 5.0536e-05 - learning_rate: 9.0000e-05
# Epoch 7/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9994 - loss: 0.0017
# Epoch 7: val_accuracy did not improve from 1.00000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 126s 355ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 2.1564e-05 - learning_rate: 9.0000e-05
# Epoch 8/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9998 - loss: 7.3219e-04
# Epoch 8: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 334ms/step - accuracy: 0.9998 - loss: 7.3221e-04 - val_accuracy: 1.0000 - val_loss: 1.8379e-05 - learning_rate: 2.7000e-05
# Epoch 9/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9997 - loss: 0.0014
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 108s 304ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 1.8363e-05 - learning_rate: 2.7000e-05
# Epoch 10/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9998 - loss: 0.0012
# Epoch 10: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 119s 333ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.1000e-05 - learning_rate: 8.1000e-06
# Epoch 11/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9997 - loss: 0.0012
# Epoch 11: val_accuracy did not improve from 1.00000
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 142s 400ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.3495e-05 - learning_rate: 8.1000e-06
# Epoch 12/12
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9999 - loss: 6.9238e-04
# Epoch 12: val_accuracy did not improve from 1.00000
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 111s 312ms/step - accuracy: 0.9999 - loss: 6.9213e-04 - val_accuracy: 1.0000 - val_loss: 2.1865e-05 - learning_rate: 2.4300e-06
# Validation Accuracy for fold 10: 100.00%

# %%
# Calculate and print average accuracies across all folds
print(f'\nAverage Training Accuracy: {np.mean(train_acc_per_fold) * 100:.2f}%')
print(f'Average Validation Accuracy: {np.mean(val_acc_per_fold) * 100:.2f}%')
# Out:
# Average Training Accuracy: 99.92%
# Average Validation Accuracy: 99.22%

# %%
# Plot Training and Validation Accuracy and Loss
epochs = [i for i in range(1)]
fig, ax = plt.subplots(1, 2, figsize=(14, 7))
train_acc = np.mean(train_acc_per_fold)  # Average training accuracy
train_loss = np.mean(train_loss_per_fold)  # Average training loss
val_acc = np.mean(val_acc_per_fold)  # Average validation accuracy
val_loss = np.mean(val_loss_per_fold)  # Average validation loss

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss', size=18, fontweight='bold',
         fontname='monospace', color='black', y=1, x=0.28, alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o', label='Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o', label='Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o', label='Training Loss')
ax[1].plot(epochs, val_loss, marker='o', label='Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')

plt.show()

# %%
# Predictions and evaluation
pred = cnn_model.predict(X_test)
pred = np.argmax(pred, axis=1)
y_test_new = np.argmax(y_test, axis=1)
print(classification_report(y_test_new, pred))

# Confusion Matrix
fig, ax = plt.subplots(1, 1, figsize=(14, 7))
sns.heatmap(confusion_matrix(y_test_new, pred), ax=ax, annot=True, cmap='Blues', alpha=0.7,
            linewidths=2, linecolor='black')
fig.text(s='Heatmap of the Confusion Matrix', size=18, fontweight='bold',
         fontname='monospace', color='black', y=0.92, x=0.28, alpha=0.8)

plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       170
#            1       0.99      1.00      0.99       203
#            2       0.96      0.98      0.97       174
#            3       0.99      0.99      0.99       156
#
#     accuracy                           0.98       703
#    macro avg       0.98      0.98      0.98       703
# weighted avg       0.98      0.98      0.98       703

# %%
# Accuracy 
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test_new, pred)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
train_eval = cnn_model.evaluate(X_train, y_train)
print(f"Training Set Accuracy: {train_eval[1] * 100:.2f}%")
final_train_acc = history.history['accuracy'][-1]  # Get the last epoch's training accuracy
final_val_acc = history.history['val_accuracy'][-1]  # Get the last epoch's validation accuracy

print(f"Final Training Accuracy: {final_train_acc * 100:.2f}%")
print(f"Final Validation Accuracy: {final_val_acc * 100:.2f}%")
# Out:
# Test Accuracy: 98.44%
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 1.0000 - loss: 5.1677e-06
# Training Set Accuracy: 100.00%
# Final Training Accuracy: 99.98%
# Final Validation Accuracy: 100.00%

# %%
# ROC Curves
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from itertools import cycle

y_test_bin = label_binarize(y_test_new, classes=[0, 1, 2, 3])  # Adjust according to your classes
n_classes = y_test_bin.shape[1]

# Get predicted probabilities
y_pred_prob = cnn_model.predict(X_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(10, 7))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')

# Plotting details
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Classification')
plt.legend(loc="lower right")
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
